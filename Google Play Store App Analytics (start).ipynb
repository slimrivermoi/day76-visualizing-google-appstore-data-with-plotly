# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
# Out:
# /var/folders/nq/ln_gwthx2kb0qfqrxc4zszmr0000gn/T/ipykernel_9350/2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
print(df_apps.shape)
print(df_apps.columns)
# Out:
# (10841, 12)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
print(df_apps.sample(5))
# Out:
#                                        App         Category  Rating  Reviews  \
# 8362                The real aquarium - HD  PERSONALIZATION    4.30   100130
# 6865          My Class Schedule: Timetable        EDUCATION    4.10     9348
# 6185         Christian Dating For Free App           DATING    3.90     8722
# 9168           Houzz Interior Design Ideas   HOUSE_AND_HOME    4.60   353813
# 64    Pistachio Launcher for Android P 9.0  PERSONALIZATION     NaN        0
#
#       Size_MBs    Installs  Type  Price Content_Rating           Genres  \
# 8362      6.15   5,000,000  Free      0       Everyone  Personalization
# 6865      6.95   1,000,000  Free      0       Everyone        Education
# 6185     13.00     500,000  Free      0     Mature 17+           Dating
# 9168      8.85  10,000,000  Free      0       Everyone     House & Home
# 64        2.30           1  Paid  $1.49       Everyone  Personalization
#
#         Last_Updated         Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
#remove Last_Updated and Android_Version columns
df_apps = df_apps[['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
       'Price', 'Content_Rating', 'Genres']]

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
#calculate total rows with NaN
print(f'Rows with NaN value: {df_apps.isna().values.sum()}')
# Out:
# Rows with NaN value: 1475

# %%
#save to new df
df_apps_clean = df_apps.dropna()

# %%
#check to make sure no na in DF
df_apps_clean.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
#total rows with duplicate based on App's name, type, and price
df_apps_clean.duplicated(subset=['App','Type','Price']).sum()
# Out:
# 1168

# %%
#remove duplicates
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App','Type','Price'])

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21     25.00        1  Free      0       Everyone  Medical
# 28     20.00        1  Paid  $1.49       Everyone   Arcade
# 47     16.00        1  Paid  $0.99       Everyone   Arcade
# 82     19.00        5  Free      0       Everyone   Arcade
# 99      4.60        5  Free      0       Everyone  Medical

# %%
filt = df_apps_clean['Rating'] == 5
df_apps_clean.loc[filt]

#over 200 rows have the highest rating -- this is not exclusive enough. 
# only apps with very few reviews are having high rating
# Out:
#                                                    App   Category  Rating  \
# 21                                 KBA-EZ Health Guide    MEDICAL    5.00
# 28                                            Ra Ga Ba       GAME    5.00
# 47                                             Mu.F.O.       GAME    5.00
# 82                                    Brick Breaker BR       GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App    MEDICAL    5.00
# ...                                                ...        ...     ...
# 2680                               Florida Wildflowers     FAMILY    5.00
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS    5.00
# 3030           CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS    5.00
# 3115                                        Oración CX  LIFESTYLE    5.00
# 4058                          Ek Bander Ne Kholi Dukan     FAMILY    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating         Genres
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
print(f'Largest App: {df_apps_clean.Size_MBs.max()}')
df_apps_clean.Size_MBs.describe()

#based on the data below, there is definitely a cap on App Size for developers.
# Out:
# Largest App: 100.0
# count   8,199.00
# mean       20.09
# std        21.65
# min         0.01
# 25%         4.90
# 50%        11.00
# 75%        28.00
# max       100.00
# Name: Size_MBs, dtype: float64

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False).head(50)

#all top 50 apps are costing 0 below.
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
#get the distribution of content rating
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import plotly
import plotly.express as px

# %%
pip install --upgrade nbformat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#to create a pie chart
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
)

#update the traces to change the text formatting
fig.update_traces(textposition='outside', textinfo='percent+label')
 
fig.show()

# %%
#make a donut chart with "hole" argument
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
hole=0.5,
)
fig.update_traces(textposition='inside', textfont_size=15, textinfo='percent')
 
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps['Installs']

#it is object, not integer yet. Need to remove , in the format
# Out:
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
#              ...
# 10836    1,000,000,000
# 10837    1,000,000,000
# 10838    1,000,000,000
# 10839    1,000,000,000
# 10840    1,000,000,000
# Name: Installs, Length: 10841, dtype: object

# %%
#replace comma with blank
df_apps_clean['Installs'] = df_apps_clean['Installs'].astype(str).str.replace(',',"")

# %%
#convert to numeric
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean['Installs'])
df_apps_clean['Installs']
# Out:
# 21                1
# 28                1
# 47                1
# 82                5
# 99                5
#             ...
# 10824    1000000000
# 10828    1000000000
# 10829    1000000000
# 10831    1000000000
# 10835    1000000000
# Name: Installs, Length: 8184, dtype: int64

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          302
# 500          199
# 1000         694
# 5000         422
# 10000        983
# 50000        456
# 100000      1095
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
#replace $ with blank
df_apps_clean['Price'] = df_apps_clean['Price'].astype(str).str.replace('$',"")
df_apps_clean['Price']
# Out:
# 21          0
# 28       1.49
# 47       0.99
# 82          0
# 99          0
#          ...
# 10824       0
# 10828       0
# 10829       0
# 10831       0
# 10835       0
# Name: Price, Length: 8199, dtype: object

# %%
df_apps_clean['Price'] = pd.to_numeric(df_apps_clean['Price'])
df_apps_clean['Price']
# Out:
# 21      0.00
# 28      1.49
# 47      0.99
# 82      0.00
# 99      0.00
#         ...
# 10824   0.00
# 10828   0.00
# 10829   0.00
# 10831   0.00
# 10835   0.00
# Name: Price, Length: 8199, dtype: float64

# %% [markdown]
# ### The most expensive apps sub $250

# %%
#Top 20 most expensive apps
df_apps_clean.sort_values(by='Price', ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# ...

# %%
#remove apps that are over $250.
filt = ~(df_apps_clean['Price']>=250)

#assign new df as df
df_apps_clean = df_apps_clean.loc[filt]
print(df_apps_clean.shape)
# Out:
# (8184, 10)

# %%
df_apps_clean.sort_values('Price', ascending=False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 2463         PTA Content Master    MEDICAL    4.20       64     41.00
#
#       Installs  Type  Price Content_Rating     Genres  Revenue_Estimate
# 2281      1000  Paid  79.99       Everyone    Medical         79,990.00
# 1407       100  Paid  39.99       Everyone    Medical          3,999.00
# 2629      1000  Paid  37.99       Everyone  Lifestyle         37,990.00
# 2481      1000  Paid  33.99       Everyone    Medical         33,990.00
# 2463      1000  Paid  29.99       Everyone    Medical         29,990.00

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean['Installs'] * df_apps_clean['Price']
df_apps_clean[['Revenue_Estimate','Installs','Price']]
# Out:
#        Revenue_Estimate    Installs  Price
# 21                 0.00           1   0.00
# 28                 1.49           1   1.49
# 47                 0.99           1   0.99
# 82                 0.00           5   0.00
# 99                 0.00           5   0.00
# ...                 ...         ...    ...
# 10824              0.00  1000000000   0.00
# 10828              0.00  1000000000   0.00
# 10829              0.00  1000000000   0.00
# 10831              0.00  1000000000   0.00
# 10835              0.00  1000000000   0.00
#
# [8184 rows x 3 columns]

# %%
#Top10 highest grossing paid app
top10_paid_apps = df_apps_clean.sort_values(by='Revenue_Estimate', ascending=False).head(10)
top10_paid_apps
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# 7954                    Bloons TD 5       FAMILY    4.60   190086     94.00
# 7633        Five Nights at Freddy's         GAME    4.60   100805     50.00
# 6746     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# ...

# %%
#count by category
top10_paid_apps['Category'].value_counts()
# Out:
# Category
# GAME           4
# FAMILY         3
# PHOTOGRAPHY    1
# LIFESTYLE      1
# WEATHER        1
# Name: count, dtype: int64

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
#total number of category
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
#barchart using px
bar = px.bar(x = top10_category.index, # index = category name
             y = top10_category.values)
 
bar.show()

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)
category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 39162676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97082000
# ART_AND_DESIGN         114233100
# DATING                 140912410
# FOOD_AND_DRINK         211677750
# EDUCATION              352852000
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               692018120
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1134006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# ENTERTAINMENT         2113660000
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# FAMILY                4437554490
# ...

# %%
#horizontal bar
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category') 
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
#Create a DF that total Apps and Installs by category
top_app_installs = df_apps_clean.groupby('Category').agg({'App': pd.Series.count, 'Installs': pd.Series.sum})
top_app_installs
# Out:
#                       App     Installs
# Category
# ART_AND_DESIGN         61    114233100
# AUTO_AND_VEHICLES      73     53129800
# BEAUTY                 42     26916200
# BOOKS_AND_REFERENCE   169   1665791655
# BUSINESS              262    692018120
# COMICS                 54     44931100
# COMMUNICATION         257  11039241530
# DATING                134    140912410
# EDUCATION             118    352852000
# ENTERTAINMENT         102   2113660000
# EVENTS                 45     15949410
# FAMILY               1606   4437554490
# FINANCE               296    455249400
# FOOD_AND_DRINK         94    211677750
# GAME                  910  13858762717
# HEALTH_AND_FITNESS    243   1134006220
# HOUSE_AND_HOME         62     97082000
# LIBRARIES_AND_DEMO     64     52083000
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# MEDICAL               292     39162676
# NEWS_AND_MAGAZINES    204   2369110650
# PARENTING              50     31116110
# ...

# %%
#Scatter plot with px
s_chart = px.scatter(data_frame=top_app_installs, 
                     x='App', 
                     y='Installs',
                     title='Category Concentration',
                     size='App',
                     hover_name=top_app_installs.index,
                     color='Installs')

s_chart.update_layout(xaxis_title='Number of Apps (Lower=More Concentrated)', 
                      yaxis_title='Installs', yaxis=dict(type='log')) 
s_chart.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean['Genres'].value_counts().sort_values()
# Out:
# Genres
# Lifestyle;Pretend Play        1
# Strategy;Education            1
# Adventure;Education           1
# Role Playing;Brain Games      1
# Tools;Education               1
#                            ...
# Personalization             298
# Productivity                301
# Education                   429
# Entertainment               467
# Tools                       718
# Name: count, Length: 114, dtype: int64

# %%
# Split the strings on the semi-colon and then .stack them.
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(stack)
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# 21     0                    Medical
# 28     0                     Arcade
# 47     0                     Arcade
# 82     0                     Arcade
# 99     0                    Medical
#                      ...
# 10824  0               Productivity
# 10828  0    Video Players & Editors
# 10829  0    Video Players & Editors
# 10831  0           News & Magazines
# 10835  0                     Arcade
# Length: 8564, dtype: object
# We now have a single column with shape: (8564,)
# Number of genres: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
genres_counts = stack.value_counts()
genres_counts
# Out:
# Tools                      719
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Personalization            298
# Lifestyle                  298
# Finance                    296
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %%
#barchart using px
bar_genres = px.bar(x=genres_counts.index[:15],
                    y=genres_counts.values[:15],
                    title="Top Genres",
                    hover_name=genres_counts.index[:15], 
                    color=genres_counts.values[:15],        #color based on count density
                    color_continuous_scale='agsunset')      #use this for shades


bar_genres.update_layout(xaxis_title='Genre', 
                         yaxis_title='Number of Apps', 
                         coloraxis_showscale=True)          #to turn on the scale for count on the right

bar_genres.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
# split between free and paid apps
df_apps_clean.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
#Group by Category
# Using as_index=False we push all the data into columns rather than end up with our Categories as the index.
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head(10)
# Out:
#               Category  Type  App
# 0       ART_AND_DESIGN  Free   58
# 1       ART_AND_DESIGN  Paid    3
# 2    AUTO_AND_VEHICLES  Free   72
# 3    AUTO_AND_VEHICLES  Paid    1
# 4               BEAUTY  Free   42
# 5  BOOKS_AND_REFERENCE  Free  161
# 6  BOOKS_AND_REFERENCE  Paid    8
# 7             BUSINESS  Free  253
# 8             BUSINESS  Paid    9
# 9               COMICS  Free   54

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
g_bar = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')
 
g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
 
g_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
fig = px.box(df_apps_clean, 
             x='Type', 
             y='Installs',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')

fig.update_layout(yaxis=dict(type='log'))

fig.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
#filter ony paid app for the DF
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']

fig = px.box(df_paid_apps, 
             x='Category', 
             y='Revenue_Estimate',
             title='How Much can Paid Apps Earn?')

fig.update_layout(yaxis=dict(type='log'),xaxis={'categoryorder':'min ascending'})

fig.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
#filter ony paid app for the DF
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']

print(f'Median Price for Paid Apps: $ {df_paid_apps['Price'].median()}')
# Out:
# Median Price for Paid Apps: $ 2.99

# %%
fig = px.box(df_paid_apps, 
             x='Category', 
             y='Price',
             title='Price per Category')

fig.update_layout(yaxis=dict(type='log'),xaxis={'categoryorder':'max descending'})

fig.show()
